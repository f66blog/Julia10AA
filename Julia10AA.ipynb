# %%
using Pkg
Pkg.add("Images")
Pkg.add("FileIO")
#Pkg.add("ImageMagick")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using Images
using FileIO

function rgb_norm(x)
    fr = 0.3
    fg = 0.6
    fb = 0.1
    sqrt(fr * red(x) + fg * green(x) + fb * blue(x))
end    


function distance(x, y)
    sum(map(rgb_norm, x - y))
end    


function to_ascii(font, im)
    d = fill(0.0, 95)
    for i = 1:95
        d[i] = distance(font[i], im)
    end    
    Char(Int(' ') + findmin(d)[2])
end


function AA(font, img)
    ny, nx = size_spatial(img)
    for iy = 1:8:ny - 7
        for ix = 1:4:nx - 3
            char = to_ascii(font, img[iy:iy+7, ix:ix+3])
            
         #  over/under exposure correction    
            arbtary_parameter = 3.5
            
            r = distance(font[1], img[iy:iy+7, ix:ix+3]) / arbtary_parameter + 1
            n = min(9, convert(Int, floor(r)))
            if char == 'R' # black
               char = ['*', '*', '*', '=', '=', 'H', 'R', 'M', '#'][n]
            elseif char == '!'         # white
               char = [' ', ' ', '`', ',', '"', '-', '~', ':', '!'][n]
            end 
            print(char)    
        end
        println()
    end    
end    

    
function main(font_file, file_name)
    # load and chop fonts
    fonts = load(font_file)
    fo = fonts[:, 1:4] # Array{RGB{Normed{UInt8, 8}}, 2}
    font = fill(fo, 95)
    for i = 1:95
        font[i] = fonts[:, 4*i-3:4*i]  #  display(font[i])    # font = 0.6 .* font
    end  
        
    # load image 
    img = load(file_name)
    
    # main    
    AA(fonts, img)    
end    

    
main("font4x8.gif", "tktt.jpg")
# Out:
# ########################################################################MMMMMMMMMMMRRMMRRRRMMMMRMRRRMMMMMMMMMMMMMMMMMMMRRRMMRRRMRRRMRR
# ttttt###t#########t#tt#########################################################MMMMMMMMMMMMMMMMRMRRMRMMMMMMMMMMMMMMMMMMRHRMMRRRMRRRMRR
# ########t######t##t##t#####t###########################################################MMMMMMMRRMRRRMMMMMMMMMMMMMMMMMMMRHRMMRHRMRRRRMM
# ####################t###tt#t##################tt####################t#########################MMMMMMMMMMMMMMMMMMMMMMMMMRHRMMRHRMRRRRMM
# #########################t############################################################################MMMMMMMMMMMMMMMMMRHHRMRHRMRHRMMM
# ########################################################t###t#################################################MMMMMMMMMRHHRMRHHRRHRMMM
# ####################################################################################################################MMMMRRRMMRHRHHRMMR
# #############################################T",,,,-""~####################################################################MMMMRRRRMMR
# ##########################################RTr",,",,```-##########################t###############################################MMMMM
# ##########################################RRjSX"T,`,"TRM##############################################################################
# #########################################RRRRRRRRSr""""-X#############################################################################
# ########################################MRRRRRRRRRRRRRT-""b###########################################################################
# ########################################RRRRRRRRRRRRRRRRMRRTSzT#######################################################################
# #################################MXS###MMMMMMRRRRRRRRRRMMM####Rj######################################################################
# #################################MRjT,"MMMMMMR-"-bRRRRMM######MH######################################################################
# ####################################MRRRTMMMR-TH""MMMMMMMRzTTrRM######################################################################
# #######################################MRjRXSTSbrbMMMMMMMMMMM#########################################################################
# MM################MMM#####################MbjSTzRMMMMMMM##############################################################################
# ################MMM###########################MMMMM#M-"SbM############################################################################
# ###############MMM###################MM#MMMMM########################################################M##M#MMMMMMMMMMMMM#M#############
# ###############MMMM##################MMMMMMMMM#############################################################MMMMMMMMMMMMMMMMMMMMMMMMM##
# ##############MMMMMMMMM###M#MMM##MMMMMMMMMMMMM##############################################MMMMMMMMMMMMMMM########MMMMMMMMMMMMMMMMMMM
# ##############MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# -"TXMRTTTTTTRr,,,b###RRMz""`,T,````"jRMMMS,,,,,,``     ``,,"rRRRRMMMRjMMMM#MMR",,HRRRbTTr"","jRRRRRRRRRRjT-""""`    `"RMMMMMMMMMMMMMMM
# TTRMRT--TTzj",,,"###MRRMr"",`,,,```-MMMMj-``` ``            `,"rTTSMRRrjMM###MRHrbRRRRRRTTX""TST"rRRRRRRRHTT-",       `"RMMMMMMMMMMMMM
# jRMRXTTXbRRH,,,,R###MRRRT"",,`````,R#MM",``   `                 ```"jRrTrM####MSTHRRRRRRRRXXTTT,,,"TRRRRRRHT"`          `"XMMMMMMMMMMM
# RRTT-TbRRbTT,,"jM###RRbT"",,,``` `~##MRH""TT",`                     `TRr"SMM##MM""zRHHHRRRRSSjT,``,,XRRRHST",```          `"RMMMMMMMMM
# RT-"-rHRMXRHSTTrM##MRzT",,``` ` `-##MMRRzbT",                        `"RjTrMMMM#M,,rHHHRRRRRRRSr",,,,TrrTT""",,,```         `"bMMMMMMM
# "","-TbRMMRT""""M##MRXr"````"",-bM##MMMRRb,                            "RbrSM####z,,THHHMMMRRRRRRHSSTrTSzSzTTTT",,``          `-MMMMMM
# `` `"TSRMMT",,,,XMMRXXX"```"MMMMMMM#MMRRH"`                            `"RzrTM###Mb`,THHRMMMRRRRRRRHjTTTTXzTrrTTTT,````         `,""""
# ````"TzMMMT",,,,"jMRRRH"```TMMMMRRMMMbT",                               `-MjTRM##MM-,"zHRMMMMMMRRRRRRRHHHHHHzTXTT""T",```  ``    `,,,,
# ````,TRMMRT,,,,`,TMMMRT,```,,`,""bRMMMMj"`                               `SMzTM####M-"XHRMMMMMMMMRRRRRRRRRRRRRRHHHSTT"",```````   ``,,
# `````rRMMj",,,,,,TMMMR",````  `,``,"X--"`                                `,bRTM#####M"THRRRRRMMMMMMMRRRRRRRRRRRRRRHjXT""",,`,````  ,,"
# `````"MMMT",,,,,"TRMMr",```  `,`       `  `                         ``````,bMRRMM####THHRMMMMMMMMMMMMMMMRRRRRRRRRRRRRHHbTT",,,,,,``,MM
# ``````TMMr",,,,,"TRMR",,,``  ``         ` `                     ```````,,,,"MRR#####MRTHMMMMMMMMMMMMMMMMMMMRRRRRRRRRRRHHHrTT",,,,``,RM
# ``````,bRT,,,,``,rRMR",,,``       `  ```` ```````           ``````````,,,,,rMRR###MSTT,"RMMMMMMMMMMMMMMMMMMMRRRRRRRRRRRRHHjTTT,,,,,"RR
# ,``````,r",,,,`,,"HMRT",,,``````````````````````````````` ```,,,,,,,,,,,"""TMMM#Mb"T",`,HRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRHHHrTTT,,"TRR
# ,,```````,,,,,`,,"TRRHT"",,,,`,,,,,,,,,,,,,,,,,,,,,``````````,,,,,,,,,""TTrRMMMSrTTT,`,HRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR