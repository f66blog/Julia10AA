# %%
using Pkg
Pkg.add("Images")
Pkg.add("FileIO")
#Pkg.add("ImageMagick")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using Images
using FileIO

function rgb_norm(x)
    fr = 0.3
    fg = 0.6
    fb = 0.1
    sqrt(fr * red(x) + fg * green(x) + fb * blue(x))
end    


function distance(x, y)
    sum(map(rgb_norm, x - y))
end    

function to_ascii(font, im)
    d = fill(0.0, 95)
    for i = 1:95
        d[i] = distance(font[i], im)
    end    
    Char(Int(' ') + findmin(d)[2])
end

function AA(font, img)
    ny, nx = size_spatial(img)
    for iy = 1:8:ny - 7
        for ix = 1:4:nx - 3
            char = to_ascii(font, img[iy:iy+7, ix:ix+3])
            
         #  over/under exposure correction    
            arbtary_parameter = 4.5
            
            r = distance(font[1], img[iy:iy+7, ix:ix+3]) / arbtary_parameter + 1
            n = convert(Int, floor(r))
            if char == 'R' # black
               char = ['*', '*', '*', '=', '=', 'H', '#', 'M', 'R'][n]
            elseif char == '!'         # white
               char = ['.', ',', '`', '`', '"', '-', '~', ':', '!'][n]
            end 
            print(char)    
        end
        println()
    end    
end    

function main(font_file, file_name)
    # load and chop fonts
    fonts = load(font_file)
    fo = fonts[:, 1:4] # Array{RGB{Normed{UInt8, 8}}, 2}
    font = fill(fo, 95)
    for i = 1:95
        font[i] = fonts[:, 4*i-3:4*i]  #  display(font[i])    # font = 0.6 .* font
    end  
        
    # load image 
    img = load(file_name)
    
    # main    
    AA(fonts, img)    
end    

main("font4x8.gif", "tktt.jpg")
# Out:
# ┌ Info: Recompiling stale cache file /home/O/.julia/compiled/v1.0/Images/H8Vxc.ji for Images [916415d5-f1e6-5110-898d-aaa5f9f070e0]
# └ @ Base loading.jl:1184
# ┌ Info: Recompiling stale cache file /home/O/.julia/compiled/v1.0/ImageMagick/0LbNX.ji for ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1]
# └ @ Base loading.jl:1184
# #########################################################################HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH==HHH==HH==HHH=
# ttttt###t#########t#tt###########################################################HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH===HH==HH==HHHH
# ########t######t##t##t#####t#############################################################HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH===HH==HH==HHHH
# ####################t###tt#t##################tt####################t###########################HHHHHHHHHHHHHHHHHHHHHHH===HH===H===HHH
# #########################t##############################################################################HHHHHHHHHHHHHHHH==HH===HH==HHH
# ########################################################t###t###################################################HHHHHHHH==HHH==HH==HHH
# ######################################################################################################################HHHHHHH======HHH
# #############################################T`````"``"######################################################################HHH==HHH=
# ##########################################HTr``````,,,`##########################t##################################################HH
# ##########################################HHjSX`T`,``T=###############################################################################
# #########################################H====HHHSr`````X#############################################################################
# ########################################H==========HHHT```b###########################################################################
# ########################################HHH======HHHHHHHHH=TSzT#######################################################################
# #################################HXS###HHH#HHH=HHHHHHHHHH#####Hj######################################################################
# #################################HHjT``#####HH"`"bHHHHHH######H=######################################################################
# ####################################HHHHTH#H="T=``HHHHHHHHzTTr=H######################################################################
# ########################################Hj=XSTSbrb###H#HHHHH##########################################################################
# ###########################################bjSTzHH###HH###############################################################################
# #################H#############################HHH###"`Sb#############################################################################
# ################HH########################HH##########################################################################################
# ################HH####################HHHHHH##############################################################################HH#HH#######
# ###############HHHHH###############HHHHHHHHHHH########################################################################HHHHHHHHHHHHHHHH
# ##############HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
HHHHHHHHHHHHHHHHHHHHHHHHHHH
# ####################################HHHH=====zT=HHj`TbbH##############H```,,,..,,,,,,`HHHHHHHHHHHH====bTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# #######HSS==HHHH##################HHHH==jbSXzjbHjT`,,`H###############HT`,,,,,`,`,,,``HHHHHHHHHHHHH==jXTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# ####HbTTTTTrXzHHHH##############HHHHH=jTTTTTTjz````,,`=H##############H`X`,,,```,,,,``=HHHHHHHHHHHHH==bT`THH############H#HHHHHHHHHHHH
# #b=`````z=HHHHHH############HHHH#jHb````,,``=r``,,````jHHH###########HHH``,,`,,`,`,,```XHHHHHHHHHHHHH=T`````rHH#######################
# HT`````====b=THHrjHHH###HHH===T``rX``,,`,,,`T``,,,```Tz=HHHHH#HH#####HH#HH``,```````````"HHHHHHHHHHHH=T```````"H######################
# =X"`````==bXHHHHHSzH###HHT=T``````bT`````,`=`,`,,,,,`TX=HHHHHHH#######HHH#b`````TT`T``````=HHHHHHHHH==XT``````,`zH####################
# =rT```jHHj=rzTXHH=`H##HHH`Tr`=````rr=`````=X```,,,`````THHHHH=jSHH#####HHHHbr```T`T`T````````=HHHHHHH==r```````,,`SHHHHHHHHHHHHHHHHHHH
# T```SXHzT```TTjX`TT##H=H`T````,,,,`j=X`===`zSTT```,,,,,``XHHHH==HHHHHH######=```Tbr=`TT```````HHHHHHHH==T``````,,,,`=HHHHHHHHHHHHHHHHH
# ``TXHHTTTTTT=r```b###HHHz``,`T`,,`,`jHH#HS``````,,,,,,,,,```r=HHHHHH=jH#####H=```=H=HbTTr````j=HHHHHHHH=jT`````,,,,,,`HHHHHHHHHHHHHHHH
# TTHHHT""TTzj`````###H=HHr``````````"#HHHj"`,,,,,,.,......,,,,``rTTSHH=rjH#####H=rb=H=HH=TTX``TST`rHHHH====TT```,,,,.,,,`HHHH##HHHHHHH#
# jHHHXTTXb===````H###H=H=T```````,``H##H```,,,,`,,...........,,,,,,,`jHrTrH####HST==H==HHH=XXTTT````TH======T``,,,,,,,,,,,`XHHHHHHHHHHH
# =HTT"TbHHbTT```jH###==bT`````,,,,`"##HH=``TT``,,..............,,,,,,`THr`SH####H``z=====HHHSSjT`,,``X=H==ST```,,,,,,,,,,,,,`HHH#######
# HT```r=HHX==STTrH###=zT````,,,,,`"###HH=zbT``,,,,,,...............,,,,`HjTrHH###H``r====HHHHH=Sr`````TrrTT```````,,,,,,,,,,,,`bHHHHHHH
# ````"TbHH#=T````H##H=Xr```,````"b###HHHH=b`,,,,,,,..,,,,..........,..,,`HbrSH####z``T===HHHHHHHH==SSTrTSzSzTTTT````,,,,,,,,,,,`"HHHHHH
# ,,,``TSHHHT`````XH#HXXX``,,`HHHHHHH##HHH=`,,,,,,,,...,...............,,,`HzrTH####b``T==HHHHHHHHHH==jTTTTXzTrrTTTT````,,,,,,,,,,``````
# ,,```TzH#HT``````jHHH==````THHHHH=HHHbT``,,,,,,,,,........,,,........,,,,"HjTH####H"``z=HHHHHHHHHHHHH=======zTXTT``T``,,,,,,,,,,,,````
# ``,,`T=HH=T``````THHHHT``,,``````bHHHHHj`,,,,,,,,,,.......,,,.......,,,.,`SHzT######"`X=HHHHHHHHHHHHHHH===========STT```,,`,,,,,,,,```
# ,,,,`rHHHj```````TH##H```,,,,,,`,,``X"``,,,,,.,,,,..,..,,,,,,,,,,,,,,,,,,,`bHTH#####H`T=HHHHHHHHHHHHHHHHHHHHHHH====jXT``````````,,,```
# ,,,,,`HHHT```````THHHr```,,,,,`,,,,,,,,,,,,,,,,,,,,,.....,,,,,,,,,,,,,,,,``bH=HH#####T==HHHHHHHHHHHHHHHHHHHHHHHHHH=====bTT````````,`HH
# ,,,,``T#Hr```````T=HH````,,,,,`,,,,,,,,,,,,,,,,,,,,,,,,,.,,,,,,,,,,,,```````HHH######HT=H################HHHHHHHHHHHH====rTT````````HH
# `,,,,``bHT```````r=H=`````,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,`````````````rHHH####STT``HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH====jTTT``````=H
# ``,,,`,`r`````````=H=T```````,,,,,`,,,,```````,,,,,,,,,,,,,,```````````````THHH#Hb`T````=HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH=====rTTT```T==
# ``,``,,,,`````````THH=T`````````````````````````````````````````````````TTrH#HHSrTTT```==========================HHHHHHH=H===jTTTTT===
# ```,```,,,````````THHH==T``````````````````TTTXTT````````````````T`````r=HHHHHz`````,``j===============================HHHHH==========
# ``````,,,,,```````zHHHH===bTTTTTTj===z==HHHHHH=======zjrTTrTTTrT`TrzXXzHH#HHHHXTTr`,,``TT=============================================
# T````````,,,,`````z=HHHHHHH=========HHH########HHHHH==============HHHHHHHHHH=====j`,,```T=============================================
# =T```````,,,,`````r=HH###HHHHHHHHHHHH################HHHHHHHHHHHHHHHHHH##H========```T```=============================================
# H=r````````,,,````TbHH###HHHHHHHH#######################################HH=======```TT``T=============================================
# HH=T````````,,,,````HH###HH###############################HTrb#########HH=======X```zT``b=============================================
# HHH=b`````````,,,,`TjHH##HHHH##########HHHHHHHHHHHHHHH#HHHTrTTH########H=======b```XT``T==============================================
# HHHH=jT````````,````THH############HHHH#HHH##############Hb"XH########HjbS==H==T``rS```rX=============================================
# HHHHHH=T```````````TzHH##########H###################################H=SXb====z``rzT```r`T============================================
# HHHHHHH=bTT```````TXjH#########HHHH######################HTTTb#######H=XSbzzzX``rXr```TT``HHHH=H======================================
# HHHHHHHH==XTTTTTTrS=HHH#######HHHHH###HHHHHHHHHHHHHHHHHHHHTTTTH#####H=zzjSXrrT`TTX````r```HHH==HHHHH==========j=======================
# HHHHHHHHH==jrTTTrb=HHHHH#H#####HHHHH###HH#H#H#HHHHHHHHH###H=bb#####HHjXzjjzbT`TXz`````````======HHHHH=================================
# HHHHHH#HHH==jjjbHHHHHHHHHHHH####HHHHH##############################H=jbSrTTTTTTbT```TT`,``T====================zz=====================
# HHHHH#####HHHHHHHHHHHHHHHHH######====H############################H====jXrXTTXjT`TrHST``"j=================jj===b=====================
# #HHHHH########HHHHHHHHHHHH#######H====HH#HHTbHHHHHHHHHHHHH==H#####H====SXXTz=HbHHH###H#####HH====================b===XT=========HHHHHH
# #############HHHHHHzzHHH#######HXTrTSTrbH#HHH###########HHHH######H====b==HHHHHH############HHHH=========================T=X=====HHHHH
